# %%
# !huggingface-cli download --resume-download KVCache-ai/DeepSeek-V2-Lite.Q2_K.gguf

# %%
# !huggingface-cli download KVCache-ai/DeepSeek-V2-Lite.Q2_K.gguf --resume-download --local-dir . --local-dir-use-symlinks False

# %%
# !huggingface-cli download --resume-download mradermacher/DeepSeek-V2-Lite-GGUF

# %%
# !huggingface-cli download mradermacher/DeepSeek-V2-Lite-GGUF DeepSeek-V2-Lite.Q2_K.gguf --resume-download
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Downloading 'DeepSeek-V2-Lite.Q2_K.gguf' to '/root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF/blobs/87540101f7e99dc3ead80651abfd18e1ee38195f3e8afaf9cb2b6625244ea7f0.incomplete'
# DeepSeek-V2-Lite.Q2_K.gguf: 100% 6.43G/6.43G [01:43<00:00, 61.9MB/s]
# Download complete. Moving file to /root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF/blobs/87540101f7e99dc3ead80651abfd18e1ee38195f3e8afaf9cb2b6625244ea7f0
# /root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF/snapshots/0f37fdf276e8094747457f0ae4d40f2e8d2521f9/DeepSeek-V2-Lite.Q2_K.gguf

# %%
/content

# %%
huggingface-cli download TheBloke/MythoMax-L2-13B-GGUF mythomax-l2-13b.q4_K_M.gguf --local-dir . --local-dir-use-symlinks False

# %%
# Base ctransformers with no GPU acceleration
pip install ctransformers>=0.2.24
# Or with CUDA GPU acceleration
pip install ctransformers[cuda]>=0.2.24
# Or with ROCm GPU acceleration
CT_HIPBLAS=1 pip install ctransformers>=0.2.24 --no-binary ctransformers
# Or with Metal GPU acceleration for macOS systems
CT_METAL=1 pip install ctransformers>=0.2.24 --no-binary ctransformers

# %%
# !pip install ctransformers
# Out:
# Collecting ctransformers
#   Downloading ctransformers-0.2.27-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from ctransformers) (0.33.4)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from ctransformers) (9.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->ctransformers) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->ctransformers) (2025.7.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->ctransformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->ctransformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->ctransformers) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->ctransformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->ctransformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub->ctransformers) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->ctransformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->ctransformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->ctransformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub->ctransformers) (2025.7.14)
# Downloading ctransformers-0.2.27-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 86.1 MB/s eta 0:00:00
# Installing collected packages: ctransformers
# Successfully installed ctransformers-0.2.27

# %%
from ctransformers import AutoModelForCausalLM

# Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
llm = AutoModelForCausalLM.from_pretrained("TheBloke/MythoMax-L2-13B-GGUF", model_file="mythomax-l2-13b.q4_K_M.gguf", model_type="llama", gpu_layers=50)

print(llm("AI is going to"))

# %%
from ctransformers import AutoModelForCausalLM

# Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
llm = AutoModelForCausalLM.from_pretrained("mradermacher/DeepSeek-V2-Lite-GGUF")

print(llm("AI is going to"))

# %%
# !rm -rf /root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF

# %%
from ctransformers import AutoModelForCausalLM

# Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
llm = AutoModelForCausalLM.from_pretrained("mradermacher/DeepSeek-V2-Lite-GGUF", model_file="DeepSeek-V2-Lite.Q2_K.gguf")

print(llm("AI is going to"))
# Out:
# Fetching 0 files: 0it [00:00, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-14-2437482576.py in <cell line: 0>()
#       2
#       3 # Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
# ----> 4 llm = AutoModelForCausalLM.from_pretrained("mradermacher/DeepSeek-V2-Lite-GGUF", model_file="DeepSeek-V2-Lite.Q2_K.gguf")
#       5
#       6 print(llm("AI is going to"))
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/hub.py in from_pretrained(cls, model_path_or_repo_id, model_type, model_file, config, lib, local_files_only, revision, hf, **kwargs)
#     173             )
#     174
# --> 175         llm = LLM(
#     176             model_path=model_path,
#     177             model_type=model_type,
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/llm.py in __init__(self, model_path, model_type, config, lib)
#     251         )
#     252         if self._llm is None:
# --> 253             raise RuntimeError(
#     254                 f"Failed to create LLM '{model_type}' from '{model_path}'."
#     255             )
#
# RuntimeError: Failed to create LLM 'gguf' from '/root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF/blobs/87540101f7e99dc3ead80651abfd18e1ee38195f3e8afaf9cb2b6625244ea7f0'.

# %%
mv /root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF/snapshots/0f37fdf276e8094747457f0ae4d40f2e8d2521f9/DeepSeek-V2-Lite.Q2_K.gguf ./My-Model.gguf

# %%
# !cp /root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF/snapshots/0f37fdf276e8094747457f0ae4d40f2e8d2521f9/DeepSeek-V2-Lite.Q2_K.gguf ./My-Model.gguf

# %%
from ctransformers import AutoModelForCausalLM

# المسار الكامل للملف الذي قمت بتنزيله
# يمكنك الحصول عليه من مخرجات أمر التنزيل السابق
local_model_path = "/root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF/snapshots/0f37fdf276e8094747457f0ae4d40f2e8d2521f9/DeepSeek-V2-Lite.Q2_K.gguf"

# قم بتحميل النموذج مباشرة من المسار المحلي
# اضبط gpu_layers إذا كان لديك GPU
llm = AutoModelForCausalLM.from_pretrained(local_model_path, model_type='gguf', gpu_layers=0)

# الآن يمكنك استخدامه
print(llm("AI is going to"))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-16-459776075.py in <cell line: 0>()
#       7 # قم بتحميل النموذج مباشرة من المسار المحلي
#       8 # اضبط gpu_layers إذا كان لديك GPU
# ----> 9 llm = AutoModelForCausalLM.from_pretrained(local_model_path, model_type='gguf', gpu_layers=0)
#      10
#      11 # الآن يمكنك استخدامه
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/hub.py in from_pretrained(cls, model_path_or_repo_id, model_type, model_file, config, lib, local_files_only, revision, hf, **kwargs)
#     173             )
#     174
# --> 175         llm = LLM(
#     176             model_path=model_path,
#     177             model_type=model_type,
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/llm.py in __init__(self, model_path, model_type, config, lib)
#     251         )
#     252         if self._llm is None:
# --> 253             raise RuntimeError(
#     254                 f"Failed to create LLM '{model_type}' from '{model_path}'."
#     255             )
#
# RuntimeError: Failed to create LLM 'gguf' from '/root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF/snapshots/0f37fdf276e8094747457f0ae4d40f2e8d2521f9/DeepSeek-V2-Lite.Q2_K.gguf'.

# %%
from ctransformers import AutoModelForCausalLM

# المسار الكامل للملف الذي قمت بتنزيله
# يمكنك الحصول عليه من مخرجات أمر التنزيل السابق
local_model_path = "My-Model.gguf"

# قم بتحميل النموذج مباشرة من المسار المحلي
# اضبط gpu_layers إذا كان لديك GPU
llm = AutoModelForCausalLM.from_pretrained(local_model_path, model_type='deepseek_v2', gpu_layers=0)

# الآن يمكنك استخدامه
print(llm("AI is going to"))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-19-595210489.py in <cell line: 0>()
#       7 # قم بتحميل النموذج مباشرة من المسار المحلي
#       8 # اضبط gpu_layers إذا كان لديك GPU
# ----> 9 llm = AutoModelForCausalLM.from_pretrained(local_model_path, model_type='deepseek_v2', gpu_layers=0)
#      10
#      11 # الآن يمكنك استخدامه
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/hub.py in from_pretrained(cls, model_path_or_repo_id, model_type, model_file, config, lib, local_files_only, revision, hf, **kwargs)
#     173             )
#     174
# --> 175         llm = LLM(
#     176             model_path=model_path,
#     177             model_type=model_type,
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/llm.py in __init__(self, model_path, model_type, config, lib)
#     251         )
#     252         if self._llm is None:
# --> 253             raise RuntimeError(
#     254                 f"Failed to create LLM '{model_type}' from '{model_path}'."
#     255             )
#
# RuntimeError: Failed to create LLM 'deepseek_v2' from 'My-Model.gguf'.

# %%
from ctransformers import AutoModelForCausalLM

# Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
llm = AutoModelForCausalLM.from_pretrained("mradermacher/DeepSeek-V2-Lite-GGUF", model_file="DeepSeek-V2-Lite.Q2_K.gguf", model_type="deepseek_v2", gpu_layers=0)

print(llm("AI is going to"))
# Out:
# Fetching 0 files: 0it [00:00, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-20-3464379008.py in <cell line: 0>()
#       2
#       3 # Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
# ----> 4 llm = AutoModelForCausalLM.from_pretrained("mradermacher/DeepSeek-V2-Lite-GGUF", model_file="DeepSeek-V2-Lite.Q2_K.gguf", model_type="deepseek_v2", gpu_layers=0)
#       5
#       6 print(llm("AI is going to"))
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/hub.py in from_pretrained(cls, model_path_or_repo_id, model_type, model_file, config, lib, local_files_only, revision, hf, **kwargs)
#     173             )
#     174
# --> 175         llm = LLM(
#     176             model_path=model_path,
#     177             model_type=model_type,
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/llm.py in __init__(self, model_path, model_type, config, lib)
#     251         )
#     252         if self._llm is None:
# --> 253             raise RuntimeError(
#     254                 f"Failed to create LLM '{model_type}' from '{model_path}'."
#     255             )
#
# RuntimeError: Failed to create LLM 'deepseek_v2' from '/root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF/blobs/87540101f7e99dc3ead80651abfd18e1ee38195f3e8afaf9cb2b6625244ea7f0'.

# %%
from ctransformers import AutoModelForCausalLM

# Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
llm = AutoModelForCausalLM.from_pretrained("mradermacher/DeepSeek-V2-Lite-GGUF", model_file="DeepSeek-V2-Lite.Q2_K.gguf")

print(llm("AI is going to"))

# %%
from ctransformers import AutoModelForCausalLM

llm = AutoModelForCausalLM.from_pretrained("/content/My-Model.gguf", model_type="deepseek")

print(llm("AI is going to"))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-22-1029276730.py in <cell line: 0>()
#       1 from ctransformers import AutoModelForCausalLM
#       2
# ----> 3 llm = AutoModelForCausalLM.from_pretrained("/content/My-Model.gguf", model_type="deepseek")
#       4
#       5 print(llm("AI is going to"))
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/hub.py in from_pretrained(cls, model_path_or_repo_id, model_type, model_file, config, lib, local_files_only, revision, hf, **kwargs)
#     173             )
#     174
# --> 175         llm = LLM(
#     176             model_path=model_path,
#     177             model_type=model_type,
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/llm.py in __init__(self, model_path, model_type, config, lib)
#     251         )
#     252         if self._llm is None:
# --> 253             raise RuntimeError(
#     254                 f"Failed to create LLM '{model_type}' from '{model_path}'."
#     255             )
#
# RuntimeError: Failed to create LLM 'deepseek' from '/content/My-Model.gguf'.

# %%
llm = AutoModelForCausalLM.from_pretrained("mradermacher/DeepSeek-V2-Lite-GGUF", model_file="/contggmlent/My-Model.gguf")
# Out:
# Fetching 0 files: 0it [00:00, ?it/s]
# Fetching 0 files: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-23-3684189524.py in <cell line: 0>()
# ----> 1 llm = AutoModelForCausalLM.from_pretrained("mradermacher/DeepSeek-V2-Lite-GGUF", model_file="/contggmlent/My-Model.gguf")
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/hub.py in from_pretrained(cls, model_path_or_repo_id, model_type, model_file, config, lib, local_files_only, revision, hf, **kwargs)
#     166             )
#     167         elif path_type == "repo":
# --> 168             model_path = cls._find_model_path_from_repo(
#     169                 model_path_or_repo_id,
#     170                 model_file,
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/hub.py in _find_model_path_from_repo(cls, repo_id, filename, local_files_only, revision)
#     207             revision=revision,
#     208         )
# --> 209         return cls._find_model_path_from_dir(path, filename=filename)
#     210
#     211     @classmethod
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/hub.py in _find_model_path_from_dir(cls, path, filename)
#     240             file = (path / filename).resolve()
#     241             if not file.is_file():
# --> 242                 raise ValueError(f"Model file '{filename}' not found in '{path}'")
#     243             return str(file)
#     244
#
# ValueError: Model file '/contggmlent/My-Model.gguf' not found in '/root/.cache/huggingface/hub/models--mradermacher--DeepSeek-V2-Lite-GGUF/snapshots/0f37fdf276e8094747457f0ae4d40f2e8d2521f9'

# %%
from ctransformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("marella/gpt-2-ggml", hf=True)
tokenizer = AutoTokenizer.from_pretrained(model)
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# ggml-model.bin:   0%|          | 0.00/251M [00:00<?, ?B/s]
# CTransformersModel has generative capabilities, as `prepare_inputs_for_generation` is explicitly defined. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipython-input-24-2800055799.py in <cell line: 0>()
#       2
#       3 model = AutoModelForCausalLM.from_pretrained("marella/gpt-2-ggml", hf=True)
# ----> 4 tokenizer = AutoTokenizer.from_pretrained(model)
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/hub.py in from_pretrained(cls, model)
#     266             )
#     267
# --> 268         return CTransformersTokenizer(model._llm)
#
# /usr/local/lib/python3.11/dist-packages/ctransformers/transformers.py in __init__(self, llm, **kwargs)
#      82 class CTransformersTokenizer(PreTrainedTokenizer):
#      83     def __init__(self, llm: LLM, **kwargs):
# ---> 84         super().__init__(**kwargs)
#      85         self._llm = llm
#      86
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils.py in __init__(self, **kwargs)
#     436         # 4. If some of the special tokens are not part of the vocab, we add them, at the end.
#     437         # the order of addition is the same as self.SPECIAL_TOKENS_ATTRIBUTES following `tokenizers`
# --> 438         self._add_tokens(
#     439             [token for token in self.all_special_tokens_extended if token not in self._added_tokens_encoder],
#     440             special_tokens=True,
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils.py in _add_tokens(self, new_tokens, special_tokens)
#     544             return added_tokens
#     545         # TODO this is fairly slow to improve!
# --> 546         current_vocab = self.get_vocab().copy()
#     547         new_idx = len(current_vocab)  # only call this once, len gives the last index + 1
#     548         for token in new_tokens:
#
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py in get_vocab(self)
#    1515             `dict[str, int]`: The vocabulary.
#    1516         """
# -> 1517         raise NotImplementedError()
#    1518
#    1519     def apply_chat_template(
#
# NotImplementedError:

# %%
from ctransformers import AutoModelForCausalLM
from transformers import AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("marella/gpt-2-ggml", hf=True)  # Load model from GGML model repo.
tokenizer = AutoTokenizer.from_pretrained("gpt2")  # Load tokenizer from original model repo.
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# CTransformersModel has generative capabilities, as `prepare_inputs_for_generation` is explicitly defined. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)
print(pipe("AI is going to", max_new_tokens=256))
# Out:
# Device set to use cpu
# CTransformersModel has generative capabilities, as `prepare_inputs_for_generation` is explicitly defined. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-27-1023579777.py in <cell line: 0>()
#       1 from transformers import pipeline
#       2
# ----> 3 pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)
#       4 print(pipe("AI is going to", max_new_tokens=256))
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1266         kwargs["processor"] = processor
#    1267
# -> 1268     return pipeline_class(model=model, framework=framework, task=task, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in __init__(self, *args, **kwargs)
#     114
#     115     def __init__(self, *args, **kwargs):
# --> 116         super().__init__(*args, **kwargs)
#     117         self.check_model_type(
#     118             TF_MODEL_FOR_CAUSAL_LM_MAPPING_NAMES if self.framework == "tf" else MODEL_FOR_CAUSAL_LM_MAPPING_NAMES
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/base.py in __init__(self, model, tokenizer, feature_extractor, image_processor, processor, modelcard, framework, task, args_parser, device, torch_dtype, binary_output, **kwargs)
#    1107         self._batch_size = kwargs.pop("batch_size", None)
#    1108         self._num_workers = kwargs.pop("num_workers", None)
# -> 1109         self._preprocess_params, self._forward_params, self._postprocess_params = self._sanitize_parameters(**kwargs)
#    1110
#    1111         # In processor only mode, we can get the modality processors from the processor
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/text_generation.py in _sanitize_parameters(self, return_full_text, return_tensors, return_text, return_type, clean_up_tokenization_spaces, prefix, handle_long_generation, stop_sequence, truncation, max_length, continue_final_message, **generate_kwargs)
#     215             generate_kwargs["eos_token_id"] = stop_sequence_ids
#     216
# --> 217         if self.assistant_model is not None:
#     218             forward_params["assistant_model"] = self.assistant_model
#     219         if self.assistant_tokenizer is not None:
#
# AttributeError: 'TextGenerationPipeline' object has no attribute 'assistant_model'

# %%
from ctransformers import AutoModelForCausalLM
from transformers import AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("marella/gpt-2-ggml", hf=True)  # Load model from GGML model repo.
tokenizer = AutoTokenizer.from_pretrained("gpt2")  # Load tokenizer from original model repo.

# %%
from ctransformers import AutoModelForCausalLM

# استخدم النموذج الذي تم تحميله في الخلية السابقة (cell_id: APba7zbSrZw6)
# model = AutoModelForCausalLM.from_pretrained("marella/gpt-2-ggml", hf=True)
# tokenizer = AutoTokenizer.from_pretrained("gpt2")

# إعادة تحميل النموذج بدون hf=True لتجنب مشاكل التوافق المحتملة
model = AutoModelForCausalLM.from_pretrained("marella/gpt-2-ggml")


prompt = "AI is going to"

# قم بتوليد النص مباشرة عن طريق استدعاء كائن النموذج
generated_text = model(prompt, max_new_tokens=50)

print(generated_text)
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
#  be in a good position."
#  (The Associated Press)

# %%
from ctransformers import AutoModelForCausalLM

# استخدم النموذج الذي تم تحميله في الخلية السابقة (cell_id: APba7zbSrZw6)
# model = AutoModelForCausalLM.from_pretrained("marella/gpt-2-ggml", hf=True)
# tokenizer = AutoTokenizer.from_pretrained("gpt2")

# إعادة تحميل النموذج بدون hf=True لتجنب مشاكل التوافق المحتملة
model = AutoModelForCausalLM.from_pretrained("marella/gpt-2-ggml")


prompt = "AI is going to"

# قم بتوليد النص مباشرة عن طريق استدعاء كائن النموذج
generated_text = model(prompt, max_new_tokens=50)

print(generated_text)
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
#  do everything possible. The biggest problem I have with it and why this one doesn't make sense in my opinion, as well has been the fact that there are no real plans for a sequel or anything like that at all."
# "I think we

# %% [markdown]
# https://github.com/marella/ctransformers

# %%
from ctransformers import AutoModelForCausalLM

# Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
llm = AutoModelForCausalLM.from_pretrained("TheBloke/MythoMax-L2-13B-GGUF", model_file="mythomax-l2-13b.Q2_K.gguf", model_type="llama", gpu_layers=0)

print(llm("AI is going to"))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
#  change our world drastically, and not necessarily in the way that we think. Artificial intelligence (AI) has long been considered a powerful tool for automating routine tasks and improving efficiency. However, as more complex systems are developed, they may begin to exhibit unexpected behaviors that challenge our understanding of what it means to be human.
# One area where this could manifest is in the field of cybersecurity. AI systems are already being used to detect and prevent cyber attacks, but as these systems become more sophisticated, they may start to behave in ways that we cannot predict or control. This could lead to serious consequences, such as autonomous weapons launching without human authorization or malicious code spreading unchecked through a network.
# Another potential issue arises from the use of AI in self-driving cars. While these vehicles hold the promise of reducing accidents and improving traffic flow, they also present serious risks if their decision-making algorithms are not perfected. An AI system designed to make split-second decisions could lead to disaster if it makes a mistake or misinterprets data.
# Perhaps the most concerning aspect of these potential issues is that we may not be

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
model = AutoModelForCausalLM.from_pretrained('fla-hub/rwkv7-2.9B-world', trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained('fla-hub/rwkv7-2.9B-world', trust_remote_code=True)
#model = model.cuda() # Supported on Nvidia/AMD/Intel eg. model.xpu()
prompt = "What is a large language model?"
messages = [
    {"role": "user", "content": prompt}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

model_inputs = tokenizer([text], return_tensors="pt").to(model.device)

generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32,
    do_sample=True,
    temperature=1.0,
    top_p=0.3,
    repetition_penalty=1.2
)
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]

response = tokenizer.batch_decode(generated_ids, skip_special_tokens=False)[0]
print(response)

# %%
# !pip install fla
# Out:
# ERROR: Could not find a version that satisfies the requirement fla (from versions: none)
# ERROR: No matching distribution found for fla

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
model = AutoModelForCausalLM.from_pretrained('fla-hub/rwkv7-2.9B-world', trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained('fla-hub/rwkv7-2.9B-world', trust_remote_code=True)
#model = model.cuda() # Supported on Nvidia/AMD/Intel eg. model.xpu()
prompt = "What is a large language model?"
messages = [
    {"role": "user", "content": prompt}
]
text = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

model_inputs = tokenizer([text], return_tensors="pt")

generated_ids = model.generate(
    **model_inputs,
    max_new_tokens=32,
    do_sample=True,
    temperature=1.0,
    top_p=0.3,
    repetition_penalty=1.2
)
generated_ids = [
    output_ids[len(input_ids):] for input_ids, output_ids in zip(model_inputs.input_ids, generated_ids)
]

response = tokenizer.batch_decode(generated_ids, skip_special_tokens=False)[0]
print(response)
# Out:
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# modeling_rwkv7.py:   0%|          | 0.00/157 [00:00<?, ?B/s]
# Encountered exception while importing fla: No module named 'fla'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2-3795064280.py in <cell line: 0>()
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 2 model = AutoModelForCausalLM.from_pretrained('fla-hub/rwkv7-2.9B-world', trust_remote_code=True)
#       3 tokenizer = AutoTokenizer.from_pretrained('fla-hub/rwkv7-2.9B-world', trust_remote_code=True)
#       4 #model = model.cuda() # Supported on Nvidia/AMD/Intel eg. model.xpu()
#       5 prompt = "What is a large language model?"
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     545                 _ = kwargs.pop("quantization_config")
#     546
# --> 547             config, kwargs = AutoConfig.from_pretrained(
#     548                 pretrained_model_name_or_path,
#     549                 return_unused_kwargs=True,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1209
#    1210         if has_remote_code and trust_remote_code:
# -> 1211             config_class = get_class_from_dynamic_module(
#    1212                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **kwargs
#    1213             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     568         code_revision = revision
#     569     # And lastly we get the class inside our newly created module
# --> 570     final_module = get_cached_module_file(
#     571         repo_id,
#     572         module_file + ".py",
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_cached_module_file(pretrained_model_name_or_path, module_file, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, _commit_hash, **deprecated_kwargs)
#     391
#     392     # Check we have all the requirements in our environment
# --> 393     modules_needed = check_imports(resolved_module_file)
#     394
#     395     # Now we move the module inside our cached dynamic modules.
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in check_imports(filename)
#     223
#     224     if len(missing_packages) > 0:
# --> 225         raise ImportError(
#     226             "This modeling file requires the following packages that were not found in your environment: "
#     227             f"{', '.join(missing_packages)}. Run `pip install {' '.join(missing_packages)}`"
#
# ImportError: This modeling file requires the following packages that were not found in your environment: fla. Run `pip install fla`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True).to(torch.float32)
tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, padding_side='left', pad_token="<s>")

text = "请介绍北京的旅游景点"
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=333, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/584 [00:00<?, ?B/s]
# configuration_rwkv5.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/RWKV/rwkv-5-world-3b:
# - configuration_rwkv5.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_rwkv5.py: 0.00B [00:00, ?B/s]
# Encountered exception while importing bitsandbytes: No module named 'bitsandbytes'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-2-2930472936.py in <cell line: 0>()
#      21
#      22
# ---> 23 model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True).to(torch.float32)
#      24 tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, padding_side='left', pad_token="<s>")
#      25
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     568         code_revision = revision
#     569     # And lastly we get the class inside our newly created module
# --> 570     final_module = get_cached_module_file(
#     571         repo_id,
#     572         module_file + ".py",
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_cached_module_file(pretrained_model_name_or_path, module_file, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, _commit_hash, **deprecated_kwargs)
#     391
#     392     # Check we have all the requirements in our environment
# --> 393     modules_needed = check_imports(resolved_module_file)
#     394
#     395     # Now we move the module inside our cached dynamic modules.
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in check_imports(filename)
#     223
#     224     if len(missing_packages) > 0:
# --> 225         raise ImportError(
#     226             "This modeling file requires the following packages that were not found in your environment: "
#     227             f"{', '.join(missing_packages)}. Run `pip install {' '.join(missing_packages)}`"
#
# ImportError: This modeling file requires the following packages that were not found in your environment: bitsandbytes. Run `pip install bitsandbytes`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2025.7.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3,>=2.2->bitsandbytes)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.2->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.2->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.2->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.46.1-py3-none-manylinux_2_24_x86_64.whl (72.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 25.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 11.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 87.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed bitsandbytes-0.46.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !pip install flash-rwkv
# Out:
# Collecting flash-rwkv
#   Downloading flash_rwkv-0.3.0-py3-none-any.whl.metadata (87 bytes)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from flash-rwkv) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (2025.7.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->flash-rwkv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->flash-rwkv) (3.0.2)
# Downloading flash_rwkv-0.3.0-py3-none-any.whl (8.4 kB)
# Installing collected packages: flash-rwkv
# Successfully installed flash-rwkv-0.3.0

# %%
# الخطوة 1: تثبيت المكتبة المطلوبة
#!pip install bitsandbytes

# الخطوة 2: تشغيل الكود الخاص بك كما هو
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""

# سيتم تحميل النموذج الآن بنجاح على المعالج بصيغة float32
model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True).to(torch.float32)
tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, padding_side='left', pad_token="<s>")

text = "请介绍北京的旅游景点" # "Please introduce Beijing's tourist attractions"
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=333, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# WARNING:bitsandbytes.cextension:The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers and GPU quantization are unavailable.
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2-260838562.py in <cell line: 0>()
#      25
#      26 # سيتم تحميل النموذج الآن بنجاح على المعالج بصيغة float32
# ---> 27 model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True).to(torch.float32)
#      28 tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, padding_side='left', pad_token="<s>")
#      29
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     580         repo_type=repo_type,
#     581     )
# --> 582     return get_class_in_module(class_name, final_module, force_reload=force_download)
#     583
#     584
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_in_module(class_name, module_path, force_reload)
#     275         # reload in both cases, unless the module is already imported and the hash hits
#     276         if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 277             module_spec.loader.exec_module(module)
#     278             module.__transformers_module_hash__ = module_hash
#     279         return getattr(module, class_name)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-5-world-3b/373ffcc47014c60c397604576044fdbb561b6a1c/modeling_rwkv5.py in <module>
#      39
#      40 try:
# ---> 41     from flash_rwkv import rwkv5_cuda_linear_attention
#      42     # Check version
#      43     required_version = pkg_resources.parse_version("0.2.1")
#
# /usr/local/lib/python3.11/dist-packages/flash_rwkv/__init__.py in <module>
# ----> 1 from .rwkv5 import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2 from .rwkv6 import Rwkv6LinearAttention, rwkv6_cuda_linear_attention
#       3
#       4 __all__ = ["Rwkv5LinearAttention", "rwkv5_cuda_linear_attention", "Rwkv6LinearAttention", "rwkv6_cuda_linear_attention"]
#
# /usr/local/lib/python3.11/dist-packages/flash_rwkv/rwkv5/__init__.py in <module>
# ----> 1 from .wkv5_op import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2
#       3 __all__ = ["Rwkv5LinearAttention", "rwkv5_cuda_linear_attention"]
#
# /usr/local/lib/python3.11/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in <module>
#     207             return (g_receptance, g_key, g_value, g_time_decay, g_time_first, None)
#     208
# --> 209 load_wkv5_cuda_kernel()
#     210
#     211 def rwkv5_cuda_linear_attention(receptance, key, value, time_decay, time_first, state):
#
# /usr/local/lib/python3.11/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in load_wkv5_cuda_kernel()
#      24             f"-D_N_={64}",
#      25             ]
# ---> 26         rwkv5_cuda_kernel = load_kernel(
#      27             name="flash_rwkv_5",
#      28             sources=cuda_sources,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py in load(name, sources, extra_cflags, extra_cuda_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, is_python_module, is_standalone, keep_intermediates)
#    1378         ...     verbose=True)
#    1379     """
# -> 1380     return _jit_compile(
#    1381         name,
#    1382         [sources] if isinstance(sources, str) else sources,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py in _jit_compile(name, sources, extra_cflags, extra_cuda_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, is_python_module, is_standalone, keep_intermediates)
#    1796                         sources = list(hipified_sources)
#    1797
# -> 1798                     _write_ninja_file_and_build_library(
#    1799                         name=name,
#    1800                         sources=sources,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py in _write_ninja_file_and_build_library(name, sources, extra_cflags, extra_cuda_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, is_standalone)
#    1886         with_cuda: Optional[bool],
#    1887         is_standalone: bool = False) -> None:
# -> 1888     verify_ninja_availability()
#    1889
#    1890     compiler = get_cxx_compiler()
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py in verify_ninja_availability()
#    1943     """Raise ``RuntimeError`` if `ninja <https://ninja-build.org/>`_ build system is not available on the system, does nothing otherwise."""
#    1944     if not is_ninja_available():
# -> 1945         raise RuntimeError("Ninja is required to load C++ extensions")
#    1946
#    1947
#
# RuntimeError: Ninja is required to load C++ extensions

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="RWKV/RWKV7-Goose-World3-2.9B-HF", trust_remote_code=True)
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)
# Out:
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# modeling_rwkv7.py:   0%|          | 0.00/157 [00:00<?, ?B/s]
# Encountered exception while importing fla: No module named 'fla'
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-7-2281179987.py in <cell line: 0>()
#       1 from transformers import pipeline
#       2
# ----> 3 pipe = pipeline("text-generation", model="RWKV/RWKV7-Goose-World3-2.9B-HF", trust_remote_code=True)
#       4 messages = [
#       5     {"role": "user", "content": "Who are you?"},
#
# /usr/local/lib/python3.11/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     929                     model = adapter_config["base_model_name_or_path"]
#     930
# --> 931         config = AutoConfig.from_pretrained(
#     932             model, _from_pipeline=task, code_revision=code_revision, **hub_kwargs, **model_kwargs
#     933         )
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1209
#    1210         if has_remote_code and trust_remote_code:
# -> 1211             config_class = get_class_from_dynamic_module(
#    1212                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **kwargs
#    1213             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     568         code_revision = revision
#     569     # And lastly we get the class inside our newly created module
# --> 570     final_module = get_cached_module_file(
#     571         repo_id,
#     572         module_file + ".py",
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_cached_module_file(pretrained_model_name_or_path, module_file, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, _commit_hash, **deprecated_kwargs)
#     391
#     392     # Check we have all the requirements in our environment
# --> 393     modules_needed = check_imports(resolved_module_file)
#     394
#     395     # Now we move the module inside our cached dynamic modules.
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in check_imports(filename)
#     223
#     224     if len(missing_packages) > 0:
# --> 225         raise ImportError(
#     226             "This modeling file requires the following packages that were not found in your environment: "
#     227             f"{', '.join(missing_packages)}. Run `pip install {' '.join(missing_packages)}`"
#
# ImportError: This modeling file requires the following packages that were not found in your environment: fla. Run `pip install fla`
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
model = AutoModelForCausalLM.from_pretrained('fla-hub/rwkv7-168M-pile', trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained('fla-hub/rwkv7-168M-pile', trust_remote_code=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/fla/utils.py:351: UserWarning: Triton is not supported on current platform, roll back to CPU.
#   warnings.warn(('Triton is not supported on current platform, roll back to CPU.'), stacklevel=1)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1-2235793417.py in <cell line: 0>()
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 2 model = AutoModelForCausalLM.from_pretrained('fla-hub/rwkv7-168M-pile', trust_remote_code=True)
#       3 tokenizer = AutoTokenizer.from_pretrained('fla-hub/rwkv7-168M-pile', trust_remote_code=True)
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     545                 _ = kwargs.pop("quantization_config")
#     546
# --> 547             config, kwargs = AutoConfig.from_pretrained(
#     548                 pretrained_model_name_or_path,
#     549                 return_unused_kwargs=True,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1209
#    1210         if has_remote_code and trust_remote_code:
# -> 1211             config_class = get_class_from_dynamic_module(
#    1212                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **kwargs
#    1213             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     568         code_revision = revision
#     569     # And lastly we get the class inside our newly created module
# --> 570     final_module = get_cached_module_file(
#     571         repo_id,
#     572         module_file + ".py",
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_cached_module_file(pretrained_model_name_or_path, module_file, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, _commit_hash, **deprecated_kwargs)
#     391
#     392     # Check we have all the requirements in our environment
# --> 393     modules_needed = check_imports(resolved_module_file)
#     394
#     395     # Now we move the module inside our cached dynamic modules.
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in check_imports(filename)
#     211     for imp in imports:
#     212         try:
# --> 213             importlib.import_module(imp)
#     214         except ImportError as exception:
#     215             logger.warning(f"Encountered exception while importing {imp}: {exception}")
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.11/dist-packages/fla/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.layers import (
#       4     ABCAttention,
#       5     Attention,
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/__init__.py in <module>
#       2 # Copyright (c) 2023-2025, Songlin Yang, Yu Zhang
#       3
# ----> 4 from .abc import ABCAttention
#       5 from .attn import Attention
#       6 from .based import BasedLinearAttention
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/abc.py in <module>
#      11 from einops import rearrange
#      12
# ---> 13 from fla.modules import FusedRMSNormGated, RMSNorm, RotaryEmbedding, ShortConvolution
#      14 from fla.modules.activations import swiglu, swish
#      15 from fla.ops.abc.chunk import chunk_abc
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.modules.convolution import ImplicitLongConvolution, LongConvolution, ShortConvolution
#       4 from fla.modules.fused_bitlinear import BitLinear, FusedBitLinear
#       5 from fla.modules.fused_cross_entropy import FusedCrossEntropyLoss
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/convolution.py in <module>
#      15 from einops import rearrange
#      16
# ---> 17 from fla.ops.utils import prepare_chunk_indices, prepare_sequence_ids
#      18 from fla.utils import get_multiprocessor_count, input_guard, is_amd
#      19
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .abc import chunk_abc
#       4 from .attn import parallel_attn
#       5 from .based import fused_chunk_based, parallel_based
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .chunk import chunk_abc
#       4
#       5 __all__ = [
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/chunk.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils import softmax_bwd, softmax_fwd
#      11 from fla.ops.utils.logcumsumexp import logcumsumexp_fwd_kernel
#      12 from fla.ops.utils.op import exp
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/__init__.py in <module>
#       2
#       3 from .asm import fp32_to_tf32_asm
# ----> 4 from .cumsum import (
#       5     chunk_global_cumsum,
#       6     chunk_global_cumsum_scalar,
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/cumsum.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils.index import prepare_chunk_indices
#      11 from fla.utils import check_shared_mem, input_guard
#      12
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/index.py in <module>
#      12
#      13
# ---> 14 @triton.autotune(
#      15     configs=[
#      16         triton.Config({}, num_warps=num_warps)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in decorator(fn)
#     366
#     367     def decorator(fn):
# --> 368         return Autotuner(fn, fn.arg_names, configs, key, reset_to_zero, restore_value, pre_hook=pre_hook,
#     369                          post_hook=post_hook, prune_configs_by=prune_configs_by, warmup=warmup, rep=rep,
#     370                          use_cuda_graph=use_cuda_graph)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in __init__(self, fn, arg_names, configs, key, reset_to_zero, restore_value, pre_hook, post_hook, prune_configs_by, warmup, rep, use_cuda_graph, do_bench)
#     128
#     129         if do_bench is None:
# --> 130             self.do_bench = driver.active.get_benchmarker()
#     131         else:
#     132             self.do_bench = do_bench
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in __getattr__(self, name)
#      21
#      22     def __getattr__(self, name):
# ---> 23         self._initialize_obj()
#      24         return getattr(self._obj, name)
#      25
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _initialize_obj(self)
#      18     def _initialize_obj(self):
#      19         if self._obj is None:
# ---> 20             self._obj = self._init_fn()
#      21
#      22     def __getattr__(self, name):
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _create_driver()
#       6     actives = [x.driver for x in backends.values() if x.driver.is_active()]
#       7     if len(actives) != 1:
# ----> 8         raise RuntimeError(f"{len(actives)} active drivers ({actives}). There should only be one.")
#       9     return actives[0]()
#      10
#
# RuntimeError: 0 active drivers ([]). There should only be one.

# %%
# !pip install flash-linear-attention==0.3.0
# !pip install 'transformers>=4.48.0'
# Out:
# Collecting flash-linear-attention==0.3.0
#   Downloading flash_linear_attention-0.3.0-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: torch>=2.5 in /usr/local/lib/python3.11/dist-packages (from flash-linear-attention==0.3.0) (2.6.0+cu124)
# Requirement already satisfied: transformers>=4.45.0 in /usr/local/lib/python3.11/dist-packages (from flash-linear-attention==0.3.0) (4.53.2)
# Collecting datasets>=3.3.0 (from flash-linear-attention==0.3.0)
#   Downloading datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from flash-linear-attention==0.3.0) (0.8.1)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from flash-linear-attention==0.3.0) (8.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (0.70.15)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.3.0->flash-linear-attention==0.3.0)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (0.33.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.3.0->flash-linear-attention==0.3.0) (6.0.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.5->flash-linear-attention==0.3.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.5->flash-linear-attention==0.3.0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.45.0->flash-linear-attention==0.3.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.45.0->flash-linear-attention==0.3.0) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.45.0->flash-linear-attention==0.3.0) (0.5.3)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.11/dist-packages (from pytest->flash-linear-attention==0.3.0) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->flash-linear-attention==0.3.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from pytest->flash-linear-attention==0.3.0) (2.19.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.3.0->flash-linear-attention==0.3.0) (3.11.15)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets>=3.3.0->flash-linear-attention==0.3.0) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=3.3.0->flash-linear-attention==0.3.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=3.3.0->flash-linear-attention==0.3.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=3.3.0->flash-linear-attention==0.3.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=3.3.0->flash-linear-attention==0.3.0) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.5->flash-linear-attention==0.3.0) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=3.3.0->flash-linear-attention==0.3.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=3.3.0->flash-linear-attention==0.3.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=3.3.0->flash-linear-attention==0.3.0) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.3.0->flash-linear-attention==0.3.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.3.0->flash-linear-attention==0.3.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.3.0->flash-linear-attention==0.3.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.3.0->flash-linear-attention==0.3.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.3.0->flash-linear-attention==0.3.0) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.3.0->flash-linear-attention==0.3.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.3.0->flash-linear-attention==0.3.0) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.3.0->flash-linear-attention==0.3.0) (1.17.0)
# Downloading flash_linear_attention-0.3.0-py3-none-any.whl (639 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 639.9/639.9 kB 33.1 MB/s eta 0:00:00
# Downloading datasets-4.0.0-py3-none-any.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.8/494.8 kB 18.9 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 16.4 MB/s eta 0:00:00
# Installing collected packages: fsspec, datasets, flash-linear-attention
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.7.0
#     Uninstalling fsspec-2025.7.0:
#       Successfully uninstalled fsspec-2025.7.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.7.0 requires fsspec==2025.7.0, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-4.0.0 flash-linear-attention-0.3.0 fsspec-2025.3.0
# Requirement already satisfied: transformers>=4.48.0 in /usr/local/lib/python3.11/dist-packages (4.53.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0) (0.33.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.48.0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.48.0) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.48.0) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.48.0) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.48.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.48.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.48.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.48.0) (2025.7.14)

# %%
# Load model directly
from transformers import AutoModelForCausalLM
model = AutoModelForCausalLM.from_pretrained("RWKV/RWKV7-Goose-World3-2.9B-HF", trust_remote_code=True, torch_dtype="auto"),
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3-3220815334.py in <cell line: 0>()
#       1 # Load model directly
#       2 from transformers import AutoModelForCausalLM
# ----> 3 model = AutoModelForCausalLM.from_pretrained("RWKV/RWKV7-Goose-World3-2.9B-HF", trust_remote_code=True, torch_dtype="auto"),
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     545                 _ = kwargs.pop("quantization_config")
#     546
# --> 547             config, kwargs = AutoConfig.from_pretrained(
#     548                 pretrained_model_name_or_path,
#     549                 return_unused_kwargs=True,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1209
#    1210         if has_remote_code and trust_remote_code:
# -> 1211             config_class = get_class_from_dynamic_module(
#    1212                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **kwargs
#    1213             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     568         code_revision = revision
#     569     # And lastly we get the class inside our newly created module
# --> 570     final_module = get_cached_module_file(
#     571         repo_id,
#     572         module_file + ".py",
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_cached_module_file(pretrained_model_name_or_path, module_file, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, _commit_hash, **deprecated_kwargs)
#     391
#     392     # Check we have all the requirements in our environment
# --> 393     modules_needed = check_imports(resolved_module_file)
#     394
#     395     # Now we move the module inside our cached dynamic modules.
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in check_imports(filename)
#     211     for imp in imports:
#     212         try:
# --> 213             importlib.import_module(imp)
#     214         except ImportError as exception:
#     215             logger.warning(f"Encountered exception while importing {imp}: {exception}")
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.11/dist-packages/fla/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.layers import (
#       4     ABCAttention,
#       5     Attention,
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/__init__.py in <module>
#       2 # Copyright (c) 2023-2025, Songlin Yang, Yu Zhang
#       3
# ----> 4 from .abc import ABCAttention
#       5 from .attn import Attention
#       6 from .based import BasedLinearAttention
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/abc.py in <module>
#      11 from einops import rearrange
#      12
# ---> 13 from fla.modules import FusedRMSNormGated, RMSNorm, RotaryEmbedding, ShortConvolution
#      14 from fla.modules.activations import swiglu, swish
#      15 from fla.ops.abc.chunk import chunk_abc
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.modules.convolution import ImplicitLongConvolution, LongConvolution, ShortConvolution
#       4 from fla.modules.fused_bitlinear import BitLinear, FusedBitLinear
#       5 from fla.modules.fused_cross_entropy import FusedCrossEntropyLoss
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/convolution.py in <module>
#      15 from einops import rearrange
#      16
# ---> 17 from fla.ops.utils import prepare_chunk_indices, prepare_sequence_ids
#      18 from fla.utils import get_multiprocessor_count, input_guard, is_amd
#      19
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .abc import chunk_abc
#       4 from .attn import parallel_attn
#       5 from .based import fused_chunk_based, parallel_based
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .chunk import chunk_abc
#       4
#       5 __all__ = [
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/chunk.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils import softmax_bwd, softmax_fwd
#      11 from fla.ops.utils.logcumsumexp import logcumsumexp_fwd_kernel
#      12 from fla.ops.utils.op import exp
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/__init__.py in <module>
#       2
#       3 from .asm import fp32_to_tf32_asm
# ----> 4 from .cumsum import (
#       5     chunk_global_cumsum,
#       6     chunk_global_cumsum_scalar,
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/cumsum.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils.index import prepare_chunk_indices
#      11 from fla.utils import check_shared_mem, input_guard
#      12
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/index.py in <module>
#      12
#      13
# ---> 14 @triton.autotune(
#      15     configs=[
#      16         triton.Config({}, num_warps=num_warps)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in decorator(fn)
#     366
#     367     def decorator(fn):
# --> 368         return Autotuner(fn, fn.arg_names, configs, key, reset_to_zero, restore_value, pre_hook=pre_hook,
#     369                          post_hook=post_hook, prune_configs_by=prune_configs_by, warmup=warmup, rep=rep,
#     370                          use_cuda_graph=use_cuda_graph)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in __init__(self, fn, arg_names, configs, key, reset_to_zero, restore_value, pre_hook, post_hook, prune_configs_by, warmup, rep, use_cuda_graph, do_bench)
#     128
#     129         if do_bench is None:
# --> 130             self.do_bench = driver.active.get_benchmarker()
#     131         else:
#     132             self.do_bench = do_bench
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in __getattr__(self, name)
#      21
#      22     def __getattr__(self, name):
# ---> 23         self._initialize_obj()
#      24         return getattr(self._obj, name)
#      25
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _initialize_obj(self)
#      18     def _initialize_obj(self):
#      19         if self._obj is None:
# ---> 20             self._obj = self._init_fn()
#      21
#      22     def __getattr__(self, name):
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _create_driver()
#       6     actives = [x.driver for x in backends.values() if x.driver.is_active()]
#       7     if len(actives) != 1:
# ----> 8         raise RuntimeError(f"{len(actives)} active drivers ({actives}). There should only be one.")
#       9     return actives[0]()
#      10
#
# RuntimeError: 0 active drivers ([]). There should only be one.

# %%
from rwkv.model import RWKV
from rwkv.utils import PIPELINE, PIPELINE_ARGS

# download models: https://huggingface.co/BlinkDL
model = RWKV(model='/fsx/BlinkDL/HF-MODEL/rwkv-4-pile-169m/RWKV-4-Pile-169M-20220807-8023', strategy='cpu fp32')
pipeline = PIPELINE(model, "20B_tokenizer.json") # 20B_tokenizer.json is in https://github.com/BlinkDL/ChatRWKV
# use pipeline = PIPELINE(model, "rwkv_vocab_v20230424") for rwkv "world" models

ctx = "\nIn a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese."
print(ctx, end='')

def my_print(s):
    print(s, end='', flush=True)

# For alpha_frequency and alpha_presence, see "Frequency and presence penalties":
# https://platform.openai.com/docs/api-reference/parameter-details

args = PIPELINE_ARGS(temperature = 1.0, top_p = 0.7, top_k = 100, # top_k = 0 then ignore
                     alpha_frequency = 0.25,
                     alpha_presence = 0.25,
                     alpha_decay = 0.996, # gradually decay the penalty
                     token_ban = [0], # ban the generation of some tokens
                     token_stop = [], # stop generation whenever you see any token here
                     chunk_len = 256) # split input into chunks to save VRAM (shorter -> slower)

pipeline.generate(ctx, token_count=200, args=args, callback=my_print)
print('\n')

out, state = model.forward([187, 510, 1563, 310, 247], None)
print(out.detach().cpu().numpy())                   # get logits
out, state = model.forward([187, 510], None)
out, state = model.forward([1563], state)           # RNN has state (use deepcopy to clone states)
out, state = model.forward([310, 247], state)
print(out.detach().cpu().numpy())                   # same result as above
print('\n')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-4-2800139636.py in <cell line: 0>()
# ----> 1 from rwkv.model import RWKV
#       2 from rwkv.utils import PIPELINE, PIPELINE_ARGS
#       3
#       4 # download models: https://huggingface.co/BlinkDL
#       5 model = RWKV(model='/fsx/BlinkDL/HF-MODEL/rwkv-4-pile-169m/RWKV-4-Pile-169M-20220807-8023', strategy='cpu fp32')
#
# ModuleNotFoundError: No module named 'rwkv'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
model = AutoModelForCausalLM.from_pretrained('fla-hub/rwkv7-168M-pile', trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained('fla-hub/rwkv7-168M-pile', trust_remote_code=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-5-2235793417.py in <cell line: 0>()
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
# ----> 2 model = AutoModelForCausalLM.from_pretrained('fla-hub/rwkv7-168M-pile', trust_remote_code=True)
#       3 tokenizer = AutoTokenizer.from_pretrained('fla-hub/rwkv7-168M-pile', trust_remote_code=True)
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     545                 _ = kwargs.pop("quantization_config")
#     546
# --> 547             config, kwargs = AutoConfig.from_pretrained(
#     548                 pretrained_model_name_or_path,
#     549                 return_unused_kwargs=True,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1209
#    1210         if has_remote_code and trust_remote_code:
# -> 1211             config_class = get_class_from_dynamic_module(
#    1212                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **kwargs
#    1213             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     568         code_revision = revision
#     569     # And lastly we get the class inside our newly created module
# --> 570     final_module = get_cached_module_file(
#     571         repo_id,
#     572         module_file + ".py",
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_cached_module_file(pretrained_model_name_or_path, module_file, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, _commit_hash, **deprecated_kwargs)
#     391
#     392     # Check we have all the requirements in our environment
# --> 393     modules_needed = check_imports(resolved_module_file)
#     394
#     395     # Now we move the module inside our cached dynamic modules.
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in check_imports(filename)
#     211     for imp in imports:
#     212         try:
# --> 213             importlib.import_module(imp)
#     214         except ImportError as exception:
#     215             logger.warning(f"Encountered exception while importing {imp}: {exception}")
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.11/dist-packages/fla/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.layers import (
#       4     ABCAttention,
#       5     Attention,
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/__init__.py in <module>
#       2 # Copyright (c) 2023-2025, Songlin Yang, Yu Zhang
#       3
# ----> 4 from .abc import ABCAttention
#       5 from .attn import Attention
#       6 from .based import BasedLinearAttention
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/abc.py in <module>
#      11 from einops import rearrange
#      12
# ---> 13 from fla.modules import FusedRMSNormGated, RMSNorm, RotaryEmbedding, ShortConvolution
#      14 from fla.modules.activations import swiglu, swish
#      15 from fla.ops.abc.chunk import chunk_abc
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.modules.convolution import ImplicitLongConvolution, LongConvolution, ShortConvolution
#       4 from fla.modules.fused_bitlinear import BitLinear, FusedBitLinear
#       5 from fla.modules.fused_cross_entropy import FusedCrossEntropyLoss
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/convolution.py in <module>
#      15 from einops import rearrange
#      16
# ---> 17 from fla.ops.utils import prepare_chunk_indices, prepare_sequence_ids
#      18 from fla.utils import get_multiprocessor_count, input_guard, is_amd
#      19
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .abc import chunk_abc
#       4 from .attn import parallel_attn
#       5 from .based import fused_chunk_based, parallel_based
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .chunk import chunk_abc
#       4
#       5 __all__ = [
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/chunk.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils import softmax_bwd, softmax_fwd
#      11 from fla.ops.utils.logcumsumexp import logcumsumexp_fwd_kernel
#      12 from fla.ops.utils.op import exp
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/__init__.py in <module>
#       2
#       3 from .asm import fp32_to_tf32_asm
# ----> 4 from .cumsum import (
#       5     chunk_global_cumsum,
#       6     chunk_global_cumsum_scalar,
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/cumsum.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils.index import prepare_chunk_indices
#      11 from fla.utils import check_shared_mem, input_guard
#      12
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/index.py in <module>
#      12
#      13
# ---> 14 @triton.autotune(
#      15     configs=[
#      16         triton.Config({}, num_warps=num_warps)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in decorator(fn)
#     366
#     367     def decorator(fn):
# --> 368         return Autotuner(fn, fn.arg_names, configs, key, reset_to_zero, restore_value, pre_hook=pre_hook,
#     369                          post_hook=post_hook, prune_configs_by=prune_configs_by, warmup=warmup, rep=rep,
#     370                          use_cuda_graph=use_cuda_graph)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in __init__(self, fn, arg_names, configs, key, reset_to_zero, restore_value, pre_hook, post_hook, prune_configs_by, warmup, rep, use_cuda_graph, do_bench)
#     128
#     129         if do_bench is None:
# --> 130             self.do_bench = driver.active.get_benchmarker()
#     131         else:
#     132             self.do_bench = do_bench
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in __getattr__(self, name)
#      21
#      22     def __getattr__(self, name):
# ---> 23         self._initialize_obj()
#      24         return getattr(self._obj, name)
#      25
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _initialize_obj(self)
#      18     def _initialize_obj(self):
#      19         if self._obj is None:
# ---> 20             self._obj = self._init_fn()
#      21
#      22     def __getattr__(self, name):
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _create_driver()
#       6     actives = [x.driver for x in backends.values() if x.driver.is_active()]
#       7     if len(actives) != 1:
# ----> 8         raise RuntimeError(f"{len(actives)} active drivers ({actives}). There should only be one.")
#       9     return actives[0]()
#      10
#
# RuntimeError: 0 active drivers ([]). There should only be one.

# %% [markdown]
# https://github.com/RWKV/rwkv.cpp

# %%
# !pip install flash-rwkv
# Out:
# Requirement already satisfied: flash-rwkv in /usr/local/lib/python3.11/dist-packages (0.3.0)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from flash-rwkv) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (4.14.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13.0->flash-rwkv) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13.0->flash-rwkv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13.0->flash-rwkv) (3.0.2)

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True).to(torch.float32)
tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, padding_side='left', pad_token="<s>")

text = "请介绍北京的旅游景点"
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=3, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# WARNING:bitsandbytes.cextension:The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers and GPU quantization are unavailable.
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Using /root/.cache/torch_extensions/py311_cu124 as PyTorch extensions root...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-1-760078224.py in <cell line: 0>()
#      21
#      22
# ---> 23 model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True).to(torch.float32)
#      24 tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-5-world-3b", trust_remote_code=True, padding_side='left', pad_token="<s>")
#      25
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     580         repo_type=repo_type,
#     581     )
# --> 582     return get_class_in_module(class_name, final_module, force_reload=force_download)
#     583
#     584
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_in_module(class_name, module_path, force_reload)
#     275         # reload in both cases, unless the module is already imported and the hash hits
#     276         if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 277             module_spec.loader.exec_module(module)
#     278             module.__transformers_module_hash__ = module_hash
#     279         return getattr(module, class_name)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-5-world-3b/373ffcc47014c60c397604576044fdbb561b6a1c/modeling_rwkv5.py in <module>
#      39
#      40 try:
# ---> 41     from flash_rwkv import rwkv5_cuda_linear_attention
#      42     # Check version
#      43     required_version = pkg_resources.parse_version("0.2.1")
#
# /usr/local/lib/python3.11/dist-packages/flash_rwkv/__init__.py in <module>
# ----> 1 from .rwkv5 import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2 from .rwkv6 import Rwkv6LinearAttention, rwkv6_cuda_linear_attention
#       3
#       4 __all__ = ["Rwkv5LinearAttention", "rwkv5_cuda_linear_attention", "Rwkv6LinearAttention", "rwkv6_cuda_linear_attention"]
#
# /usr/local/lib/python3.11/dist-packages/flash_rwkv/rwkv5/__init__.py in <module>
# ----> 1 from .wkv5_op import Rwkv5LinearAttention, rwkv5_cuda_linear_attention
#       2
#       3 __all__ = ["Rwkv5LinearAttention", "rwkv5_cuda_linear_attention"]
#
# /usr/local/lib/python3.11/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in <module>
#     207             return (g_receptance, g_key, g_value, g_time_decay, g_time_first, None)
#     208
# --> 209 load_wkv5_cuda_kernel()
#     210
#     211 def rwkv5_cuda_linear_attention(receptance, key, value, time_decay, time_first, state):
#
# /usr/local/lib/python3.11/dist-packages/flash_rwkv/rwkv5/wkv5_op.py in load_wkv5_cuda_kernel()
#      24             f"-D_N_={64}",
#      25             ]
# ---> 26         rwkv5_cuda_kernel = load_kernel(
#      27             name="flash_rwkv_5",
#      28             sources=cuda_sources,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py in load(name, sources, extra_cflags, extra_cuda_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, is_python_module, is_standalone, keep_intermediates)
#    1378         ...     verbose=True)
#    1379     """
# -> 1380     return _jit_compile(
#    1381         name,
#    1382         [sources] if isinstance(sources, str) else sources,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py in _jit_compile(name, sources, extra_cflags, extra_cuda_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, is_python_module, is_standalone, keep_intermediates)
#    1796                         sources = list(hipified_sources)
#    1797
# -> 1798                     _write_ninja_file_and_build_library(
#    1799                         name=name,
#    1800                         sources=sources,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py in _write_ninja_file_and_build_library(name, sources, extra_cflags, extra_cuda_cflags, extra_ldflags, extra_include_paths, build_directory, verbose, with_cuda, is_standalone)
#    1886         with_cuda: Optional[bool],
#    1887         is_standalone: bool = False) -> None:
# -> 1888     verify_ninja_availability()
#    1889
#    1890     compiler = get_cxx_compiler()
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/cpp_extension.py in verify_ninja_availability()
#    1943     """Raise ``RuntimeError`` if `ninja <https://ninja-build.org/>`_ build system is not available on the system, does nothing otherwise."""
#    1944     if not is_ninja_available():
# -> 1945         raise RuntimeError("Ninja is required to load C++ extensions")
#    1946
#    1947
#
# RuntimeError: Ninja is required to load C++ extensions

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("RWKV/v6-Finch-7B-HF", trust_remote_code=True).to(torch.float32)
tokenizer = AutoTokenizer.from_pretrained("RWKV/v6-Finch-7B-HF", trust_remote_code=True)

text = "请介绍北京的旅游景点"
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=333, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# config.json:   0%|          | 0.00/610 [00:00<?, ?B/s]
# configuration_rwkv6.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/RWKV/v6-Finch-7B-HF:
# - configuration_rwkv6.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_rwkv6.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/RWKV/v6-Finch-7B-HF:
# - modeling_rwkv6.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# /usr/local/lib/python3.11/dist-packages/fla/utils.py:351: UserWarning: Triton is not supported on current platform, roll back to CPU.
#   warnings.warn(('Triton is not supported on current platform, roll back to CPU.'), stacklevel=1)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-2-1466749924.py in <cell line: 0>()
#      21
#      22
# ---> 23 model = AutoModelForCausalLM.from_pretrained("RWKV/v6-Finch-7B-HF", trust_remote_code=True).to(torch.float32)
#      24 tokenizer = AutoTokenizer.from_pretrained("RWKV/v6-Finch-7B-HF", trust_remote_code=True)
#      25
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     580         repo_type=repo_type,
#     581     )
# --> 582     return get_class_in_module(class_name, final_module, force_reload=force_download)
#     583
#     584
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_in_module(class_name, module_path, force_reload)
#     275         # reload in both cases, unless the module is already imported and the hash hits
#     276         if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 277             module_spec.loader.exec_module(module)
#     278             module.__transformers_module_hash__ = module_hash
#     279         return getattr(module, class_name)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/v6-Finch-7B-HF/02946e470978a56fc96bc8c47cb942c50bc9c71a/modeling_rwkv6.py in <module>
#      39 from .configuration_rwkv6 import Rwkv6Config
#      40 try:
# ---> 41     from fla.ops.rwkv6 import fused_recurrent_rwkv6
#      42 except ImportError:
#      43     print("Required module is not installed. Please install it using the following commands:")
#
# /usr/local/lib/python3.11/dist-packages/fla/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.layers import (
#       4     ABCAttention,
#       5     Attention,
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/__init__.py in <module>
#       2 # Copyright (c) 2023-2025, Songlin Yang, Yu Zhang
#       3
# ----> 4 from .abc import ABCAttention
#       5 from .attn import Attention
#       6 from .based import BasedLinearAttention
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/abc.py in <module>
#      11 from einops import rearrange
#      12
# ---> 13 from fla.modules import FusedRMSNormGated, RMSNorm, RotaryEmbedding, ShortConvolution
#      14 from fla.modules.activations import swiglu, swish
#      15 from fla.ops.abc.chunk import chunk_abc
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.modules.convolution import ImplicitLongConvolution, LongConvolution, ShortConvolution
#       4 from fla.modules.fused_bitlinear import BitLinear, FusedBitLinear
#       5 from fla.modules.fused_cross_entropy import FusedCrossEntropyLoss
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/convolution.py in <module>
#      15 from einops import rearrange
#      16
# ---> 17 from fla.ops.utils import prepare_chunk_indices, prepare_sequence_ids
#      18 from fla.utils import get_multiprocessor_count, input_guard, is_amd
#      19
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .abc import chunk_abc
#       4 from .attn import parallel_attn
#       5 from .based import fused_chunk_based, parallel_based
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .chunk import chunk_abc
#       4
#       5 __all__ = [
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/chunk.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils import softmax_bwd, softmax_fwd
#      11 from fla.ops.utils.logcumsumexp import logcumsumexp_fwd_kernel
#      12 from fla.ops.utils.op import exp
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/__init__.py in <module>
#       2
#       3 from .asm import fp32_to_tf32_asm
# ----> 4 from .cumsum import (
#       5     chunk_global_cumsum,
#       6     chunk_global_cumsum_scalar,
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/cumsum.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils.index import prepare_chunk_indices
#      11 from fla.utils import check_shared_mem, input_guard
#      12
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/index.py in <module>
#      12
#      13
# ---> 14 @triton.autotune(
#      15     configs=[
#      16         triton.Config({}, num_warps=num_warps)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in decorator(fn)
#     366
#     367     def decorator(fn):
# --> 368         return Autotuner(fn, fn.arg_names, configs, key, reset_to_zero, restore_value, pre_hook=pre_hook,
#     369                          post_hook=post_hook, prune_configs_by=prune_configs_by, warmup=warmup, rep=rep,
#     370                          use_cuda_graph=use_cuda_graph)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in __init__(self, fn, arg_names, configs, key, reset_to_zero, restore_value, pre_hook, post_hook, prune_configs_by, warmup, rep, use_cuda_graph, do_bench)
#     128
#     129         if do_bench is None:
# --> 130             self.do_bench = driver.active.get_benchmarker()
#     131         else:
#     132             self.do_bench = do_bench
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in __getattr__(self, name)
#      21
#      22     def __getattr__(self, name):
# ---> 23         self._initialize_obj()
#      24         return getattr(self._obj, name)
#      25
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _initialize_obj(self)
#      18     def _initialize_obj(self):
#      19         if self._obj is None:
# ---> 20             self._obj = self._init_fn()
#      21
#      22     def __getattr__(self, name):
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _create_driver()
#       6     actives = [x.driver for x in backends.values() if x.driver.is_active()]
#       7     if len(actives) != 1:
# ----> 8         raise RuntimeError(f"{len(actives)} active drivers ({actives}). There should only be one.")
#       9     return actives[0]()
#      10
#
# RuntimeError: 0 active drivers ([]). There should only be one.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n', '\n').replace('\n\n', '\n')
    input = input.strip().replace('\r\n', '\n').replace('\n\n', '\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""

model = AutoModelForCausalLM.from_pretrained("RWKV/v6-Finch-7B-HF", trust_remote_code=True).to(torch.float32)
tokenizer = AutoTokenizer.from_pretrained("RWKV/v6-Finch-7B-HF", trust_remote_code=True)

texts = ["请介绍北京的旅游景点", "介绍一下大熊猫", "乌兰察布"]
prompts = [generate_prompt(text) for text in texts]

inputs = tokenizer(prompts, return_tensors="pt", padding=True)
outputs = model.generate(inputs["input_ids"], max_new_tokens=128, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )

for output in outputs:
    print(tokenizer.decode(output.tolist(), skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3-2329150742.py in <cell line: 0>()
#      20 Assistant:"""
#      21
# ---> 22 model = AutoModelForCausalLM.from_pretrained("RWKV/v6-Finch-7B-HF", trust_remote_code=True).to(torch.float32)
#      23 tokenizer = AutoTokenizer.from_pretrained("RWKV/v6-Finch-7B-HF", trust_remote_code=True)
#      24
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     580         repo_type=repo_type,
#     581     )
# --> 582     return get_class_in_module(class_name, final_module, force_reload=force_download)
#     583
#     584
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_in_module(class_name, module_path, force_reload)
#     275         # reload in both cases, unless the module is already imported and the hash hits
#     276         if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 277             module_spec.loader.exec_module(module)
#     278             module.__transformers_module_hash__ = module_hash
#     279         return getattr(module, class_name)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/v6-Finch-7B-HF/02946e470978a56fc96bc8c47cb942c50bc9c71a/modeling_rwkv6.py in <module>
#      39 from .configuration_rwkv6 import Rwkv6Config
#      40 try:
# ---> 41     from fla.ops.rwkv6 import fused_recurrent_rwkv6
#      42 except ImportError:
#      43     print("Required module is not installed. Please install it using the following commands:")
#
# /usr/local/lib/python3.11/dist-packages/fla/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.layers import (
#       4     ABCAttention,
#       5     Attention,
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/__init__.py in <module>
#       2 # Copyright (c) 2023-2025, Songlin Yang, Yu Zhang
#       3
# ----> 4 from .abc import ABCAttention
#       5 from .attn import Attention
#       6 from .based import BasedLinearAttention
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/abc.py in <module>
#      11 from einops import rearrange
#      12
# ---> 13 from fla.modules import FusedRMSNormGated, RMSNorm, RotaryEmbedding, ShortConvolution
#      14 from fla.modules.activations import swiglu, swish
#      15 from fla.ops.abc.chunk import chunk_abc
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.modules.convolution import ImplicitLongConvolution, LongConvolution, ShortConvolution
#       4 from fla.modules.fused_bitlinear import BitLinear, FusedBitLinear
#       5 from fla.modules.fused_cross_entropy import FusedCrossEntropyLoss
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/convolution.py in <module>
#      15 from einops import rearrange
#      16
# ---> 17 from fla.ops.utils import prepare_chunk_indices, prepare_sequence_ids
#      18 from fla.utils import get_multiprocessor_count, input_guard, is_amd
#      19
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .abc import chunk_abc
#       4 from .attn import parallel_attn
#       5 from .based import fused_chunk_based, parallel_based
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .chunk import chunk_abc
#       4
#       5 __all__ = [
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/chunk.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils import softmax_bwd, softmax_fwd
#      11 from fla.ops.utils.logcumsumexp import logcumsumexp_fwd_kernel
#      12 from fla.ops.utils.op import exp
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/__init__.py in <module>
#       2
#       3 from .asm import fp32_to_tf32_asm
# ----> 4 from .cumsum import (
#       5     chunk_global_cumsum,
#       6     chunk_global_cumsum_scalar,
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/cumsum.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils.index import prepare_chunk_indices
#      11 from fla.utils import check_shared_mem, input_guard
#      12
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/index.py in <module>
#      12
#      13
# ---> 14 @triton.autotune(
#      15     configs=[
#      16         triton.Config({}, num_warps=num_warps)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in decorator(fn)
#     366
#     367     def decorator(fn):
# --> 368         return Autotuner(fn, fn.arg_names, configs, key, reset_to_zero, restore_value, pre_hook=pre_hook,
#     369                          post_hook=post_hook, prune_configs_by=prune_configs_by, warmup=warmup, rep=rep,
#     370                          use_cuda_graph=use_cuda_graph)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in __init__(self, fn, arg_names, configs, key, reset_to_zero, restore_value, pre_hook, post_hook, prune_configs_by, warmup, rep, use_cuda_graph, do_bench)
#     128
#     129         if do_bench is None:
# --> 130             self.do_bench = driver.active.get_benchmarker()
#     131         else:
#     132             self.do_bench = do_bench
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in __getattr__(self, name)
#      21
#      22     def __getattr__(self, name):
# ---> 23         self._initialize_obj()
#      24         return getattr(self._obj, name)
#      25
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _initialize_obj(self)
#      18     def _initialize_obj(self):
#      19         if self._obj is None:
# ---> 20             self._obj = self._init_fn()
#      21
#      22     def __getattr__(self, name):
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _create_driver()
#       6     actives = [x.driver for x in backends.values() if x.driver.is_active()]
#       7     if len(actives) != 1:
# ----> 8         raise RuntimeError(f"{len(actives)} active drivers ({actives}). There should only be one.")
#       9     return actives[0]()
#      10
#
# RuntimeError: 0 active drivers ([]). There should only be one.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-6-world-7b", trust_remote_code=True).to(torch.float32)
tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-6-world-7b", trust_remote_code=True, padding_side='left', pad_token="<s>")

text = "请介绍北京的旅游景点"
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=333, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# config.json:   0%|          | 0.00/610 [00:00<?, ?B/s]
# configuration_rwkv6.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/RWKV/rwkv-6-world-7b:
# - configuration_rwkv6.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_rwkv6.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/RWKV/rwkv-6-world-7b:
# - modeling_rwkv6.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-4-1455904792.py in <cell line: 0>()
#      21
#      22
# ---> 23 model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-6-world-7b", trust_remote_code=True).to(torch.float32)
#      24 tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-6-world-7b", trust_remote_code=True, padding_side='left', pad_token="<s>")
#      25
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     580
#     581         if has_remote_code and trust_remote_code:
# --> 582             model_class = get_class_from_dynamic_module(
#     583                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **hub_kwargs, **kwargs
#     584             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     580         repo_type=repo_type,
#     581     )
# --> 582     return get_class_in_module(class_name, final_module, force_reload=force_download)
#     583
#     584
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_in_module(class_name, module_path, force_reload)
#     275         # reload in both cases, unless the module is already imported and the hash hits
#     276         if getattr(module, "__transformers_module_hash__", "") != module_hash:
# --> 277             module_spec.loader.exec_module(module)
#     278             module.__transformers_module_hash__ = module_hash
#     279         return getattr(module, class_name)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/rwkv-6-world-7b/61a156acc8cf539ad741d7eef756e404c203335c/modeling_rwkv6.py in <module>
#      39 from .configuration_rwkv6 import Rwkv6Config
#      40 try:
# ---> 41     from fla.ops.rwkv6.recurrent_fuse import fused_recurrent_rwkv6
#      42 except ImportError:
#      43     print("Required module is not installed. Please install it using the following commands:")
#
# /usr/local/lib/python3.11/dist-packages/fla/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.layers import (
#       4     ABCAttention,
#       5     Attention,
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/__init__.py in <module>
#       2 # Copyright (c) 2023-2025, Songlin Yang, Yu Zhang
#       3
# ----> 4 from .abc import ABCAttention
#       5 from .attn import Attention
#       6 from .based import BasedLinearAttention
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/abc.py in <module>
#      11 from einops import rearrange
#      12
# ---> 13 from fla.modules import FusedRMSNormGated, RMSNorm, RotaryEmbedding, ShortConvolution
#      14 from fla.modules.activations import swiglu, swish
#      15 from fla.ops.abc.chunk import chunk_abc
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.modules.convolution import ImplicitLongConvolution, LongConvolution, ShortConvolution
#       4 from fla.modules.fused_bitlinear import BitLinear, FusedBitLinear
#       5 from fla.modules.fused_cross_entropy import FusedCrossEntropyLoss
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/convolution.py in <module>
#      15 from einops import rearrange
#      16
# ---> 17 from fla.ops.utils import prepare_chunk_indices, prepare_sequence_ids
#      18 from fla.utils import get_multiprocessor_count, input_guard, is_amd
#      19
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .abc import chunk_abc
#       4 from .attn import parallel_attn
#       5 from .based import fused_chunk_based, parallel_based
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .chunk import chunk_abc
#       4
#       5 __all__ = [
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/chunk.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils import softmax_bwd, softmax_fwd
#      11 from fla.ops.utils.logcumsumexp import logcumsumexp_fwd_kernel
#      12 from fla.ops.utils.op import exp
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/__init__.py in <module>
#       2
#       3 from .asm import fp32_to_tf32_asm
# ----> 4 from .cumsum import (
#       5     chunk_global_cumsum,
#       6     chunk_global_cumsum_scalar,
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/cumsum.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils.index import prepare_chunk_indices
#      11 from fla.utils import check_shared_mem, input_guard
#      12
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/index.py in <module>
#      12
#      13
# ---> 14 @triton.autotune(
#      15     configs=[
#      16         triton.Config({}, num_warps=num_warps)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in decorator(fn)
#     366
#     367     def decorator(fn):
# --> 368         return Autotuner(fn, fn.arg_names, configs, key, reset_to_zero, restore_value, pre_hook=pre_hook,
#     369                          post_hook=post_hook, prune_configs_by=prune_configs_by, warmup=warmup, rep=rep,
#     370                          use_cuda_graph=use_cuda_graph)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in __init__(self, fn, arg_names, configs, key, reset_to_zero, restore_value, pre_hook, post_hook, prune_configs_by, warmup, rep, use_cuda_graph, do_bench)
#     128
#     129         if do_bench is None:
# --> 130             self.do_bench = driver.active.get_benchmarker()
#     131         else:
#     132             self.do_bench = do_bench
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in __getattr__(self, name)
#      21
#      22     def __getattr__(self, name):
# ---> 23         self._initialize_obj()
#      24         return getattr(self._obj, name)
#      25
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _initialize_obj(self)
#      18     def _initialize_obj(self):
#      19         if self._obj is None:
# ---> 20             self._obj = self._init_fn()
#      21
#      22     def __getattr__(self, name):
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _create_driver()
#       6     actives = [x.driver for x in backends.values() if x.driver.is_active()]
#       7     if len(actives) != 1:
# ----> 8         raise RuntimeError(f"{len(actives)} active drivers ({actives}). There should only be one.")
#       9     return actives[0]()
#      10
#
# RuntimeError: 0 active drivers ([]). There should only be one.

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("RWKV/HF_v5-Eagle-7B", trust_remote_code=True).to(torch.float32)
tokenizer = AutoTokenizer.from_pretrained("RWKV/HF_v5-Eagle-7B", trust_remote_code=True)

text = "请介绍北京的旅游景点"
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=333, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# config.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# configuration_rwkv5.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/RWKV/HF_v5-Eagle-7B:
# - configuration_rwkv5.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_rwkv5.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/RWKV/HF_v5-Eagle-7B:
# - modeling_rwkv5.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# pytorch_model.bin:   0%|          | 0.00/15.0G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-5-3868041232.py in <cell line: 0>()
#      21
#      22
# ---> 23 model = AutoModelForCausalLM.from_pretrained("RWKV/HF_v5-Eagle-7B", trust_remote_code=True).to(torch.float32)
#      24 tokenizer = AutoTokenizer.from_pretrained("RWKV/HF_v5-Eagle-7B", trust_remote_code=True)
#      25
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     591                 model_class.register_for_auto_class(auto_class=cls)
#     592             model_class = add_generation_mixin_to_remote_model(model_class)
# --> 593             return model_class.from_pretrained(
#     594                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     595             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in _wrapper(*args, **kwargs)
#     309         old_dtype = torch.get_default_dtype()
#     310         try:
# --> 311             return func(*args, **kwargs)
#     312         finally:
#     313             torch.set_default_dtype(old_dtype)
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4764         with ContextManagers(model_init_context):
#    4765             # Let's make sure we don't run the init function of buffer modules
# -> 4766             model = cls(config, *model_args, **model_kwargs)
#    4767
#    4768         # Make sure to tie the weights correctly
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/HF_v5-Eagle-7B/bb01ae9434eb9f4934c1ebe486eb7d3e25883d72/modeling_rwkv5.py in __init__(self, config)
#     774     def __init__(self, config):
#     775         super().__init__(config)
# --> 776         self.rwkv = Rwkv5Model(config)
#     777         self.head = nn.Linear(config.hidden_size, config.vocab_size, bias=False)
#     778
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/HF_v5-Eagle-7B/bb01ae9434eb9f4934c1ebe486eb7d3e25883d72/modeling_rwkv5.py in __init__(self, config)
#     619
#     620         # Initialize weights and apply final processing
# --> 621         self.post_init()
#     622
#     623     def get_input_embeddings(self):
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in post_init(self)
#    2079                 for module in self._keep_in_fp32_modules:
#    2080                     if module not in unique_module_names:
# -> 2081                         raise ValueError(
#    2082                             f"{module} was specified in the `_keep_in_fp32_modules` list, but is not part of the modules in"
#    2083                             f" {self.__class__.__name__}"
#
# ValueError: time_first was specified in the `_keep_in_fp32_modules` list, but is not part of the modules in Rwkv5Model

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

def generate_prompt(instruction, input=""):
    instruction = instruction.strip().replace('\r\n','\n').replace('\n\n','\n')
    input = input.strip().replace('\r\n','\n').replace('\n\n','\n')
    if input:
        return f"""Instruction: {instruction}

Input: {input}

Response:"""
    else:
        return f"""User: hi

Assistant: Hi. I am your assistant and I will provide expert full response in full details. Please feel free to ask any question and I will always answer it.

User: {instruction}

Assistant:"""


model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-4-world-3b", trust_remote_code=True).to(torch.float32)
tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-4-world-3b", trust_remote_code=True)

text = "请介绍北京的旅游景点"
prompt = generate_prompt(text)

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=333, do_sample=True, temperature=1.0, top_p=0.3, top_k=0, )
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("RWKV/rwkv-4-3b-pile")
tokenizer = AutoTokenizer.from_pretrained("RWKV/rwkv-4-3b-pile")

prompt = "\nIn a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese."

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=40)
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/522 [00:00<?, ?B/s]
# pytorch_model.bin.index.json: 0.00B [00:00, ?B/s]
# Fetching 7 files:   0%|          | 0/7 [00:00<?, ?it/s]
# pytorch_model-00003-of-00007.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# pytorch_model-00001-of-00007.bin:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# pytorch_model-00005-of-00007.bin:   0%|          | 0.00/1.91G [00:00<?, ?B/s]
# pytorch_model-00004-of-00007.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# pytorch_model-00007-of-00007.bin:   0%|          | 0.00/515M [00:00<?, ?B/s]
# pytorch_model-00002-of-00007.bin:   0%|          | 0.00/1.99G [00:00<?, ?B/s]
# pytorch_model-00006-of-00007.bin:   0%|          | 0.00/1.60G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Loading checkpoint shards:   0%|          | 0/7 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/264 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# In a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese.
#
# The dragons were discovered by a team of scientists from the University of Hong Kong, who were exploring the remote, previously unexplored valley in Tibet.
#
# The dragons were discovered by a team

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("RWKV/HF_v5-Eagle-7B", trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("RWKV/HF_v5-Eagle-7B")

prompt = "\nIn a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese."

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=40)
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2-2397258049.py in <cell line: 0>()
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
#       2
# ----> 3 model = AutoModelForCausalLM.from_pretrained("RWKV/HF_v5-Eagle-7B", trust_remote_code=True)
#       4 tokenizer = AutoTokenizer.from_pretrained("RWKV/HF_v5-Eagle-7B")
#       5
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     591                 model_class.register_for_auto_class(auto_class=cls)
#     592             model_class = add_generation_mixin_to_remote_model(model_class)
# --> 593             return model_class.from_pretrained(
#     594                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     595             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in _wrapper(*args, **kwargs)
#     309         old_dtype = torch.get_default_dtype()
#     310         try:
# --> 311             return func(*args, **kwargs)
#     312         finally:
#     313             torch.set_default_dtype(old_dtype)
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4764         with ContextManagers(model_init_context):
#    4765             # Let's make sure we don't run the init function of buffer modules
# -> 4766             model = cls(config, *model_args, **model_kwargs)
#    4767
#    4768         # Make sure to tie the weights correctly
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/HF_v5-Eagle-7B/bb01ae9434eb9f4934c1ebe486eb7d3e25883d72/modeling_rwkv5.py in __init__(self, config)
#     774     def __init__(self, config):
#     775         super().__init__(config)
# --> 776         self.rwkv = Rwkv5Model(config)
#     777         self.head = nn.Linear(config.hidden_size, config.vocab_size, bias=False)
#     778
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/HF_v5-Eagle-7B/bb01ae9434eb9f4934c1ebe486eb7d3e25883d72/modeling_rwkv5.py in __init__(self, config)
#     619
#     620         # Initialize weights and apply final processing
# --> 621         self.post_init()
#     622
#     623     def get_input_embeddings(self):
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in post_init(self)
#    2079                 for module in self._keep_in_fp32_modules:
#    2080                     if module not in unique_module_names:
# -> 2081                         raise ValueError(
#    2082                             f"{module} was specified in the `_keep_in_fp32_modules` list, but is not part of the modules in"
#    2083                             f" {self.__class__.__name__}"
#
# ValueError: time_first was specified in the `_keep_in_fp32_modules` list, but is not part of the modules in Rwkv5Model

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# المسار إلى المجلد المحلي الذي يحتوي على الملفات المعدّلة
local_model_path = "RWKV/HF_v5-Eagle-7B"

# قم بالتحميل من المسار المحلي
model = AutoModelForCausalLM.from_pretrained(local_model_path, trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained(local_model_path)

prompt = "\nIn a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese."

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=40)
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-4-2219580564.py in <cell line: 0>()
#       5
#       6 # قم بالتحميل من المسار المحلي
# ----> 7 model = AutoModelForCausalLM.from_pretrained(local_model_path, trust_remote_code=True)
#       8 tokenizer = AutoTokenizer.from_pretrained(local_model_path)
#       9
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     591                 model_class.register_for_auto_class(auto_class=cls)
#     592             model_class = add_generation_mixin_to_remote_model(model_class)
# --> 593             return model_class.from_pretrained(
#     594                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     595             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in _wrapper(*args, **kwargs)
#     309         old_dtype = torch.get_default_dtype()
#     310         try:
# --> 311             return func(*args, **kwargs)
#     312         finally:
#     313             torch.set_default_dtype(old_dtype)
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4764         with ContextManagers(model_init_context):
#    4765             # Let's make sure we don't run the init function of buffer modules
# -> 4766             model = cls(config, *model_args, **model_kwargs)
#    4767
#    4768         # Make sure to tie the weights correctly
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/HF_v5-Eagle-7B/bb01ae9434eb9f4934c1ebe486eb7d3e25883d72/modeling_rwkv5.py in __init__(self, config)
#     774     def __init__(self, config):
#     775         super().__init__(config)
# --> 776         self.rwkv = Rwkv5Model(config)
#     777         self.head = nn.Linear(config.hidden_size, config.vocab_size, bias=False)
#     778
#
# ~/.cache/huggingface/modules/transformers_modules/RWKV/HF_v5-Eagle-7B/bb01ae9434eb9f4934c1ebe486eb7d3e25883d72/modeling_rwkv5.py in __init__(self, config)
#     619
#     620         # Initialize weights and apply final processing
# --> 621         self.post_init()
#     622
#     623     def get_input_embeddings(self):
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in post_init(self)
#    2079                 for module in self._keep_in_fp32_modules:
#    2080                     if module not in unique_module_names:
# -> 2081                         raise ValueError(
#    2082                             f"{module} was specified in the `_keep_in_fp32_modules` list, but is not part of the modules in"
#    2083                             f" {self.__class__.__name__}"
#
# ValueError: time_first was specified in the `_keep_in_fp32_modules` list, but is not part of the modules in Rwkv5Model

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("RWKV/RWKV7-Goose-World3-1.5B-HF", trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("RWKV/RWKV7-Goose-World3-1.5B-HF")

prompt = "\nIn a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese."

inputs = tokenizer(prompt, return_tensors="pt")
output = model.generate(inputs["input_ids"], max_new_tokens=40)
print(tokenizer.decode(output[0].tolist(), skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-11-1061194383.py in <cell line: 0>()
#       1 from transformers import AutoModelForCausalLM, AutoTokenizer
#       2
# ----> 3 model = AutoModelForCausalLM.from_pretrained("RWKV/RWKV7-Goose-World3-1.5B-HF", trust_remote_code=True)
#       4 tokenizer = AutoTokenizer.from_pretrained("RWKV/RWKV7-Goose-World3-1.5B-HF")
#       5
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     545                 _ = kwargs.pop("quantization_config")
#     546
# --> 547             config, kwargs = AutoConfig.from_pretrained(
#     548                 pretrained_model_name_or_path,
#     549                 return_unused_kwargs=True,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/configuration_auto.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1209
#    1210         if has_remote_code and trust_remote_code:
# -> 1211             config_class = get_class_from_dynamic_module(
#    1212                 class_ref, pretrained_model_name_or_path, code_revision=code_revision, **kwargs
#    1213             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     568         code_revision = revision
#     569     # And lastly we get the class inside our newly created module
# --> 570     final_module = get_cached_module_file(
#     571         repo_id,
#     572         module_file + ".py",
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in get_cached_module_file(pretrained_model_name_or_path, module_file, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, _commit_hash, **deprecated_kwargs)
#     391
#     392     # Check we have all the requirements in our environment
# --> 393     modules_needed = check_imports(resolved_module_file)
#     394
#     395     # Now we move the module inside our cached dynamic modules.
#
# /usr/local/lib/python3.11/dist-packages/transformers/dynamic_module_utils.py in check_imports(filename)
#     211     for imp in imports:
#     212         try:
# --> 213             importlib.import_module(imp)
#     214         except ImportError as exception:
#     215             logger.warning(f"Encountered exception while importing {imp}: {exception}")
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.11/dist-packages/fla/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.layers import (
#       4     ABCAttention,
#       5     Attention,
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/__init__.py in <module>
#       2 # Copyright (c) 2023-2025, Songlin Yang, Yu Zhang
#       3
# ----> 4 from .abc import ABCAttention
#       5 from .attn import Attention
#       6 from .based import BasedLinearAttention
#
# /usr/local/lib/python3.11/dist-packages/fla/layers/abc.py in <module>
#      11 from einops import rearrange
#      12
# ---> 13 from fla.modules import FusedRMSNormGated, RMSNorm, RotaryEmbedding, ShortConvolution
#      14 from fla.modules.activations import swiglu, swish
#      15 from fla.ops.abc.chunk import chunk_abc
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from fla.modules.convolution import ImplicitLongConvolution, LongConvolution, ShortConvolution
#       4 from fla.modules.fused_bitlinear import BitLinear, FusedBitLinear
#       5 from fla.modules.fused_cross_entropy import FusedCrossEntropyLoss
#
# /usr/local/lib/python3.11/dist-packages/fla/modules/convolution.py in <module>
#      15 from einops import rearrange
#      16
# ---> 17 from fla.ops.utils import prepare_chunk_indices, prepare_sequence_ids
#      18 from fla.utils import get_multiprocessor_count, input_guard, is_amd
#      19
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .abc import chunk_abc
#       4 from .attn import parallel_attn
#       5 from .based import fused_chunk_based, parallel_based
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2
# ----> 3 from .chunk import chunk_abc
#       4
#       5 __all__ = [
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/abc/chunk.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils import softmax_bwd, softmax_fwd
#      11 from fla.ops.utils.logcumsumexp import logcumsumexp_fwd_kernel
#      12 from fla.ops.utils.op import exp
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/__init__.py in <module>
#       2
#       3 from .asm import fp32_to_tf32_asm
# ----> 4 from .cumsum import (
#       5     chunk_global_cumsum,
#       6     chunk_global_cumsum_scalar,
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/cumsum.py in <module>
#       8 import triton.language as tl
#       9
# ---> 10 from fla.ops.utils.index import prepare_chunk_indices
#      11 from fla.utils import check_shared_mem, input_guard
#      12
#
# /usr/local/lib/python3.11/dist-packages/fla/ops/utils/index.py in <module>
#      12
#      13
# ---> 14 @triton.autotune(
#      15     configs=[
#      16         triton.Config({}, num_warps=num_warps)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in decorator(fn)
#     366
#     367     def decorator(fn):
# --> 368         return Autotuner(fn, fn.arg_names, configs, key, reset_to_zero, restore_value, pre_hook=pre_hook,
#     369                          post_hook=post_hook, prune_configs_by=prune_configs_by, warmup=warmup, rep=rep,
#     370                          use_cuda_graph=use_cuda_graph)
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/autotuner.py in __init__(self, fn, arg_names, configs, key, reset_to_zero, restore_value, pre_hook, post_hook, prune_configs_by, warmup, rep, use_cuda_graph, do_bench)
#     128
#     129         if do_bench is None:
# --> 130             self.do_bench = driver.active.get_benchmarker()
#     131         else:
#     132             self.do_bench = do_bench
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in __getattr__(self, name)
#      21
#      22     def __getattr__(self, name):
# ---> 23         self._initialize_obj()
#      24         return getattr(self._obj, name)
#      25
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _initialize_obj(self)
#      18     def _initialize_obj(self):
#      19         if self._obj is None:
# ---> 20             self._obj = self._init_fn()
#      21
#      22     def __getattr__(self, name):
#
# /usr/local/lib/python3.11/dist-packages/triton/runtime/driver.py in _create_driver()
#       6     actives = [x.driver for x in backends.values() if x.driver.is_active()]
#       7     if len(actives) != 1:
# ----> 8         raise RuntimeError(f"{len(actives)} active drivers ({actives}). There should only be one.")
#       9     return actives[0]()
#      10
#
# RuntimeError: 0 active drivers ([]). There should only be one.

# %%
from rwkv.model import RWKV
from rwkv.utils import PIPELINE, PIPELINE_ARGS

# download models: https://huggingface.co/BlinkDL
model = RWKV(model='/fsx/BlinkDL/HF-MODEL/rwkv-4-pile-169m/RWKV-4-Pile-169M-20220807-8023', strategy='cpu fp32')
pipeline = PIPELINE(model, "20B_tokenizer.json") # 20B_tokenizer.json is in https://github.com/BlinkDL/ChatRWKV
# use pipeline = PIPELINE(model, "rwkv_vocab_v20230424") for rwkv "world" models

ctx = "\nIn a shocking finding, scientist discovered a herd of dragons living in a remote, previously unexplored valley, in Tibet. Even more surprising to the researchers was the fact that the dragons spoke perfect Chinese."
print(ctx, end='')

def my_print(s):
    print(s, end='', flush=True)

# For alpha_frequency and alpha_presence, see "Frequency and presence penalties":
# https://platform.openai.com/docs/api-reference/parameter-details

args = PIPELINE_ARGS(temperature = 1.0, top_p = 0.7, top_k = 100, # top_k = 0 then ignore
                     alpha_frequency = 0.25,
                     alpha_presence = 0.25,
                     alpha_decay = 0.996, # gradually decay the penalty
                     token_ban = [0], # ban the generation of some tokens
                     token_stop = [], # stop generation whenever you see any token here
                     chunk_len = 256) # split input into chunks to save VRAM (shorter -> slower)

pipeline.generate(ctx, token_count=200, args=args, callback=my_print)
print('\n')

out, state = model.forward([187, 510, 1563, 310, 247], None)
print(out.detach().cpu().numpy())                   # get logits
out, state = model.forward([187, 510], None)
out, state = model.forward([1563], state)           # RNN has state (use deepcopy to clone states)
out, state = model.forward([310, 247], state)
print(out.detach().cpu().numpy())                   # same result as above
print('\n')
# Out:
# RWKV_JIT_ON 1 RWKV_CUDA_ON 0 RESCALE_LAYER 0
#
# Loading /fsx/BlinkDL/HF-MODEL/rwkv-4-pile-169m/RWKV-4-Pile-169M-20220807-8023.pth ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-10-2800139636.py in <cell line: 0>()
#       3
#       4 # download models: https://huggingface.co/BlinkDL
# ----> 5 model = RWKV(model='/fsx/BlinkDL/HF-MODEL/rwkv-4-pile-169m/RWKV-4-Pile-169M-20220807-8023', strategy='cpu fp32')
#       6 pipeline = PIPELINE(model, "20B_tokenizer.json") # 20B_tokenizer.json is in https://github.com/BlinkDL/ChatRWKV
#       7 # use pipeline = PIPELINE(model, "rwkv_vocab_v20230424") for rwkv "world" models
#
# /usr/local/lib/python3.11/dist-packages/torch/jit/_script.py in init_then_script(self, *args, **kwargs)
#     304         def init_then_script(self, *args, **kwargs):
#     305             num_methods = len(cls._methods)
# --> 306             original_init(self, *args, **kwargs)
#     307             added_methods_in_init = len(cls._methods) > num_methods
#     308
#
# /usr/local/lib/python3.11/dist-packages/rwkv/model.py in __init__(self, model, strategy, verbose, convert_and_save_and_exit)
#     490         prxxx(f'Loading {args.MODEL_NAME} ...')
#     491         with torch.no_grad():
# --> 492             self.w = torch.load(args.MODEL_NAME, map_location='cpu') # load model to CPU first
#     493             gc.collect()
#     494             w = self.w
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1423         pickle_load_args["encoding"] = "utf-8"
#    1424
# -> 1425     with _open_file_like(f, "rb") as opened_file:
#    1426         if _is_zipfile(opened_file):
#    1427             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     749 def _open_file_like(name_or_buffer, mode):
#     750     if _is_path(name_or_buffer):
# --> 751         return _open_file(name_or_buffer, mode)
#     752     else:
#     753         if "w" in mode:
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     730 class _open_file(_opener):
#     731     def __init__(self, name, mode):
# --> 732         super().__init__(open(name, mode))
#     733
#     734     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/fsx/BlinkDL/HF-MODEL/rwkv-4-pile-169m/RWKV-4-Pile-169M-20220807-8023.pth'

# %%
# !pip install rwkv
# Out:
# Collecting rwkv
#   Downloading rwkv-0.8.29-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.11/dist-packages (from rwkv) (0.21.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers>=0.13.2->rwkv) (0.33.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->rwkv) (2025.7.14)
# Downloading rwkv-0.8.29-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.1/410.1 kB 20.5 MB/s eta 0:00:00
# Installing collected packages: rwkv
# Successfully installed rwkv-0.8.29

# %% [markdown]
# https://huggingface.co/docs/transformers/model_doc/rwkv

# %%
import torch
from transformers import AutoTokenizer, RwkvConfig, RwkvModel

model = RwkvModel.from_pretrained("sgugger/rwkv-430M-pile")
tokenizer = AutoTokenizer.from_pretrained("sgugger/rwkv-430M-pile")

inputs = tokenizer("This is an example.", return_tensors="pt")
# Feed everything to the model
outputs = model(inputs["input_ids"])
output_whole = outputs.last_hidden_state

outputs = model(inputs["input_ids"][:, :2])
output_one = outputs.last_hidden_state

# Using the state computed on the first inputs, we will get the same output
outputs = model(inputs["input_ids"][:, 2:], state=outputs.state)
output_two = outputs.last_hidden_state

torch.allclose(torch.cat([output_one, output_two], dim=1), output_whole, atol=1e-5)
# Out:
# config.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/861M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/861M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/264 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# True

# %%
# !wget https://huggingface.co/BlinkDL/rwkv7-g1/resolve/main/rwkv7-g1-0.1b-20250307-ctx4096.pth

# %%
import torch
from transformers import AutoTokenizer, RwkvConfig, RwkvModel

model = RwkvModel.from_pretrained("RWKV/RWKV7-Goose-World3-1.5B-HF")
tokenizer = AutoTokenizer.from_pretrained("RWKV/RWKV7-Goose-World3-1.5B-HF")

inputs = tokenizer("This is an example.", return_tensors="pt")
# Feed everything to the model
outputs = model(inputs["input_ids"])
output_whole = outputs.last_hidden_state

outputs = model(inputs["input_ids"][:, :2])
output_one = outputs.last_hidden_state

# Using the state computed on the first inputs, we will get the same output
outputs = model(inputs["input_ids"][:, 2:], state=outputs.state)
output_two = outputs.last_hidden_state

torch.allclose(torch.cat([output_one, output_two], dim=1), output_whole, atol=1e-5)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# You are using a model of type rwkv7 to instantiate a model of type rwkv. This is not supported for all configurations of models and can yield errors.
# model.safetensors:   0%|          | 0.00/3.05G [00:00<?, ?B/s]
# Some weights of RwkvModel were not initialized from the model checkpoint at RWKV/RWKV7-Goose-World3-1.5B-HF and are newly initialized: ['blocks.0.attention.key.weight', 'blocks.0.attention.output.weight', 'blocks.0.attention.receptance.weight', 'blocks.0.attention.time_decay', 'blocks.0.attention.time_first', 'blocks.0.attention.time_mix_key', 'blocks.0.attention.time_mix_receptance', 'blocks.0.attention.time_mix_value', 'blocks.0.attention.value.weight', 'blocks.0.feed_forward.key.weight', 'blocks.0.feed_forward.receptance.weight', 'blocks.0.feed_forward.time_mix_key', 'blocks.0.feed_forward.time_mix_receptance', 'blocks.0.feed_forward.value.weight', 'blocks.0.ln1.bias', 'blocks.0.ln1.weight', 'blocks.0.ln2.bias', 'blocks.0.ln2.weight', 'blocks.0.pre_ln.bias', 'blocks.0.pre_ln.weight', 'blocks.1.attention.key.weight', 'blocks.1.attention.output.weight', 'blocks.1.attention.receptance.weight', 'blocks.1.attention.time_decay', 'blocks.1.attention.time_first', 'blocks.1.attention.time_mix_key', 'blocks.1.attention.time_mix_receptance', 'blocks.1.attention.time_mix_value', 'blocks.1.attention.value.weight', 'blocks.1.feed_forward.key.weight', 'blocks.1.feed_forward.receptance.weight', 'blocks.1.feed_forward.time_mix_key', 'blocks.1.feed_forward.time_mix_receptance', 'blocks.1.feed_forward.value.weight', 'blocks.1.ln1.bias', 'blocks.1.ln1.weight', 'blocks.1.ln2.bias', 'blocks.1.ln2.weight', 'blocks.10.attention.key.weight', 'blocks.10.attention.output.weight', 'blocks.10.attention.receptance.weight', 'blocks.10.attention.time_decay', 'blocks.10.attention.time_first', 'blocks.10.attention.time_mix_key', 'blocks.10.attention.time_mix_receptance', 'blocks.10.attention.time_mix_value', 'blocks.10.attention.value.weight', 'blocks.10.feed_forward.key.weight', 'blocks.10.feed_forward.receptance.weight', 'blocks.10.feed_forward.time_mix_key', 'blocks.10.feed_forward.time_mix_receptance', 'blocks.10.feed_forward.value.weight', 'blocks.10.ln1.bias', 'blocks.10.ln1.weight', 'blocks.10.ln2.bias', 'blocks.10.ln2.weight', 'blocks.11.attention.key.weight', 'blocks.11.attention.output.weight', 'blocks.11.attention.receptance.weight', 'blocks.11.attention.time_decay', 'blocks.11.attention.time_first', 'blocks.11.attention.time_mix_key', 'blocks.11.attention.time_mix_receptance', 'blocks.11.attention.time_mix_value', 'blocks.11.attention.value.weight', 'blocks.11.feed_forward.key.weight', 'blocks.11.feed_forward.receptance.weight', 'blocks.11.feed_forward.time_mix_key', 'blocks.11.feed_forward.time_mix_receptance', 'blocks.11.feed_forward.value.weight', 'blocks.11.ln1.bias', 'blocks.11.ln1.weight', 'blocks.11.ln2.bias', 'blocks.11.ln2.weight', 'blocks.12.attention.key.weight', 'blocks.12.attention.output.weight', 'blocks.12.attention.receptance.weight', 'blocks.12.attention.time_decay', 'blocks.12.attention.time_first', 'blocks.12.attention.time_mix_key', 'blocks.12.attention.time_mix_receptance', 'blocks.12.attention.time_mix_value', 'blocks.12.attention.value.weight', 'blocks.12.feed_forward.key.weight', 'blocks.12.feed_forward.receptance.weight', 'blocks.12.feed_forward.time_mix_key', 'blocks.12.feed_forward.time_mix_receptance', 'blocks.12.feed_forward.value.weight', 'blocks.12.ln1.bias', 'blocks.12.ln1.weight', 'blocks.12.ln2.bias', 'blocks.12.ln2.weight', 'blocks.13.attention.key.weight', 'blocks.13.attention.output.weight', 'blocks.13.attention.receptance.weight', 'blocks.13.attention.time_decay', 'blocks.13.attention.time_first', 'blocks.13.attention.time_mix_key', 'blocks.13.attention.time_mix_receptance', 'blocks.13.attention.time_mix_value', 'blocks.13.attention.value.weight', 'blocks.13.feed_forward.key.weight', 'blocks.13.feed_forward.receptance.weight', 'blocks.13.feed_forward.time_mix_key', 'blocks.13.feed_forward.time_mix_receptance', 'blocks.13.feed_forward.value.weight', 'blocks.13.ln1.bias', 'blocks.13.ln1.weight', 'blocks.13.ln2.bias', 'blocks.13.ln2.weight', 'blocks.14.attention.key.weight', 'blocks.14.attention.output.weight', ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# The repository RWKV/RWKV7-Goose-World3-1.5B-HF contains custom code which must be executed to correctly load the model. You can inspect the repository content at https://hf.co/RWKV/RWKV7-Goose-World3-1.5B-HF .
#  You can inspect the repository content at https://hf.co/RWKV/RWKV7-Goose-World3-1.5B-HF.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] Y
# hf_rwkv_tokenizer.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/RWKV/RWKV7-Goose-World3-1.5B-HF:
# - hf_rwkv_tokenizer.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# rwkv_vocab_v20230424.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/45.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# False
